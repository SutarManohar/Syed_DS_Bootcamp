# %% [markdown]
# # **Visual Summaization**
#
# Bivariate Analysis
#
# Numerical vs Numerical
#
# 1. Scatter plot
# 2. Line plot
# 3. Heatmap for correlation
# 4. joint plot
#
# Categorical vs Numerical
#
# 1. Bar chart
# 2. Violin chart
# 3. Categorical box plot
# 4. Swar plot
#
# Categorical vs Categorical
#
# 1. Bar chart
# 2. Grouped bar chart
# 3. Point plot

# %% [markdown]
# # **Scatter plot**  (Numerical vs Numerical)
# Scatter plots are the graphs that present the relationship between two variables in a data-set. It represents data points on a two-dimensional plane or on a Cartesian system. The independent variable or attribute is plotted on the X-axis, while the dependent variable is plotted on the Y-axis.

# %%
from google.colab import files
from IPython.display import Image

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-1a820a23-b27f-48bf-9bec-f57f41bb7e41" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1a820a23-b27f-48bf-9bec-f57f41bb7e41">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 1_eCSB5GxAgssw6XOCn6L_AQ.png to 1_eCSB5GxAgssw6XOCn6L_AQ.png

# %%
Image('1_eCSB5GxAgssw6XOCn6L_AQ.png',width = 400)

# %% [markdown]
# # **Line Plot** (Numerical vs Numerical)
#
# Line charts are used to represent the relation between two data X and Y on a different axis.

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0bf3672d-fa99-42ea-93bb-7999b27d7aec" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0bf3672d-fa99-42ea-93bb-7999b27d7aec">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving simpleplot-300x169.png to simpleplot-300x169.png

# %%
Image('simpleplot-300x169.png',width = 400)

# %% [markdown]
# # **A correlation heatmap**  (Numerical vs Numerical)
#
#
# A correlation heatmap is a graphical representation of a correlation matrix representing the correlation between different variables. The value of correlation can take any value from -1 to 1.

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b36ad93c-379f-42e1-934c-acfa1f036cc5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b36ad93c-379f-42e1-934c-acfa1f036cc5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Screenshot-2020-09-29-at-11.19.40-AM.png to Screenshot-2020-09-29-at-11.19.40-AM.png

# %%
Image('Screenshot-2020-09-29-at-11.19.40-AM.png',width=400)

# %% [markdown]
# # **Joint plot** (Numerical vs Numerical)
#
# A Jointplot comprises three plots. Out of the three, one plot displays a bivariate graph which shows how the dependent variable(Y) varies with the independent variable(X). Another plot is placed horizontally at the top of the bivariate graph and it shows the distribution of the independent variable(X)

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-fdff63a2-f354-4c64-bc9b-57e2549027f9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fdff63a2-f354-4c64-bc9b-57e2549027f9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Screenshot367.png to Screenshot367.png

# %%
Image('Screenshot367.png',width=400)

# %% [markdown]
# #**Bar chart** (Categorical vs Numerical)
#
# A bar chart or bar graph is a chart or graph that presents categorical data with rectangular bars with heights or lengths proportional to the values that they represent. The bars can be plotted vertically or horizontally. A vertical bar chart is sometimes called a column chart.

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2f9dda3d-7f1d-4aa2-9b1c-aa6fbb90b565" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2f9dda3d-7f1d-4aa2-9b1c-aa6fbb90b565">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving bar-sample.png to bar-sample.png

# %%
Image('bar-sample.png',width = 400)

# %% [markdown]
# # **Violin chart**  (Categorical vs Numerical)
#
# Violin plots are a combination of box plot and histograms. It portrays the distribution, median, interquartile range of data. So we see that iqr and median are the statistical information provided by box plot whereas distribution is being provided by the histogram.

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4f3f4b0d-71e9-4512-80de-f6312ddcd27a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4f3f4b0d-71e9-4512-80de-f6312ddcd27a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving violin-plot-example.png to violin-plot-example.png

# %%
Image('violin-plot-example.png',width = 400)

# %% [markdown]
# # **Categorical box plot**  (Categorical vs Numerical)
#
# Categorical Distribution Plots. We have two different kinds of categorical distribution plots, box plots and violin plots. These kinds of plots allow us to choose a numerical variable, like age, and plot the distribution of age for each category in a selected categorical variable.

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4ec44c9b-0da8-4afa-8e90-c87b2509fab2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4ec44c9b-0da8-4afa-8e90-c87b2509fab2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 1_LNSsOkVT0QEkNyQA1Rai1w.png to 1_LNSsOkVT0QEkNyQA1Rai1w.png

# %%
Image('1_LNSsOkVT0QEkNyQA1Rai1w.png',width=400)

# %% [markdown]
# #**Bar chart** (Categorical vs Categorical)
#
#
# A bar chart or bar graph is a chart or graph that presents categorical data with rectangular bars with heights or lengths proportional to the values that they represent. The bars can be plotted vertically or horizontally. A vertical bar chart is sometimes called a column chart.

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-5f40486d-d987-42e2-b832-99c7f92340f9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5f40486d-d987-42e2-b832-99c7f92340f9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving bar-chart-bestpracti.jpg to bar-chart-bestpracti.jpg

# %%
Image('bar-chart-bestpracti.jpg',width=400)

# %% [markdown]
# # **Grouped bar chart** (Categorical vs Categorical)
#
# grouped bar charts are Bar charts in which multiple sets of data items are compared, with a single color used to denote a specific series across all sets. As with basic Bar charts, both vertical and horizontal versions of grouped bar charts are available.

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6d9d8be4-89d4-4613-9985-abd6ed1f5f85" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6d9d8be4-89d4-4613-9985-abd6ed1f5f85">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving grouped2.png to grouped2.png

# %%
Image('grouped2.png',width=400)

# %% [markdown]
# # **Point plot** (Categorical vs Categorical)
#
# A point plot represents an estimate of central tendency for a numeric variable by the position of scatter plot points and provides some indication of the uncertainty around that estimate using error bars.

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4f67970f-24d4-4bb7-b8d6-a8776c36f7ce" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4f67970f-24d4-4bb7-b8d6-a8776c36f7ce">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Screenshot339.png to Screenshot339.png

# %%
Image('Screenshot339.png')
