# %% [markdown]
# # Normal Distribution

# %% [markdown]
# - In Normal Distribution, data is symmetrically distributed with no skew.
# when plotted on a graph, the data follows a bell shape
#
# - A normal distribution is an arrangement of a data set in which most values cluster in the middle of the range and the rest taper off symmetrically toward either extreme.
#
# - Normal distribution, also known as the Gaussian distribution, is a probability distribution that is symmetric about the mean, showing that data near the mean are more frequent in occurrence than data far from the mean. In graph form, normal distribution will appear as a bell curve.

# %%
from google.colab import files
from IPython.display import Image

# %%
uploaded = files.upload()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-ed2fd71b4a2f> in <module>()
# ----> 1 uploaded = files.upload()
#
# NameError: name 'files' is not defined

# %%
Image('Plain Normal Curve.png')

# %% [markdown]
# ## Table of contents
#
# 1. Why do normal distributions matter?
# 2. What are the properties of normal distributions?
# 3. Empirical rule
# 4. Central limit theorem
# 5. Formula of the normal curve
# 6. What is the standard normal distribution?
# 7. Frequently asked questions about normal distributions

# %% [markdown]
# ##Properties of normal distributions

# %% [markdown]
# ###Normal distributions have key characteristics that are easy to spot in graphs:
#
# - The mean, median and mode are exactly the same.
# - The distribution is symmetric about the mean—half the values fall below the mean and half above the mean.
# - The distribution can be described by two values: the mean and the standard deviation.

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-94f0d291-4bf3-4f75-be43-d3e38dd17268" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-94f0d291-4bf3-4f75-be43-d3e38dd17268">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving normal-distribution.jpg to normal-distribution.jpg

# %%
Image('normal-distribution.jpg')

# %% [markdown]
# ##Empirical rule
#
# The empirical rule, or the 68-95-99.7 rule, tells you where most of your values lie in a normal distribution:
#
# - Around 68% of values are within 1 standard deviation from the mean.
# - Around 95% of values are within 2 standard deviations from the mean.
# - Around 99.7% of values are within 3 standard deviations from the mean.

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-32475449-c15c-4e54-a687-b7a56f332fe5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-32475449-c15c-4e54-a687-b7a56f332fe5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving empirical-rule1.png to empirical-rule1.png

# %%
Image('empirical-rule1.png')

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-132e64ad-805d-4597-aa85-8f31d7402542" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-132e64ad-805d-4597-aa85-8f31d7402542">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving bell-curve.jpg to bell-curve.jpg

# %%
Image('bell-curve.jpg')

# %% [markdown]
# ## Standard deviation
#
# - The standard deviation is the average amount of variability in your dataset.
#
# It tells you, on average, how far each score lies from the mean. The larger the standard deviation, the more variable the data set is.
#
# ###There are six steps for finding the standard deviation by hand:
#
# - List each score and find their mean.
# - Subtract the mean from each score to get the deviation from the mean.
# - Square each of these deviations.
# - Add up all of the squared deviations.
# - Divide the sum of the squared deviations by n – 1 (for a sample) or N (for a population).
# - Find the square root of the number you found.

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-90ec8468-d315-4c6e-a0d2-ca996ef97e29" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-90ec8468-d315-4c6e-a0d2-ca996ef97e29">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving standard-deviation-formula-1626765976.png to standard-deviation-formula-1626765976.png

# %%
Image('standard-deviation-formula-1626765976.png')
